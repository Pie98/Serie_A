# %%
import pandas as pd

# %%
for i in range(0, 19):
    file_path = fr'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 ({i}).csv'
    print(f"df_{i} = pd.read_csv(r'{file_path}',parse_dates=['Date'], dayfirst=True )")
# Out:
# df_0 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (0).csv',parse_dates=['Date'], dayfirst=True )
# df_1 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (1).csv',parse_dates=['Date'], dayfirst=True )
# df_2 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (2).csv',parse_dates=['Date'], dayfirst=True )
# df_3 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (3).csv',parse_dates=['Date'], dayfirst=True )
# df_4 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (4).csv',parse_dates=['Date'], dayfirst=True )
# df_5 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (5).csv',parse_dates=['Date'], dayfirst=True )
# df_6 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (6).csv',parse_dates=['Date'], dayfirst=True )
# df_7 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (7).csv',parse_dates=['Date'], dayfirst=True )
# ...

# %%
df_0 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (0).csv',parse_dates=['Date'], dayfirst=True )
df_1 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (1).csv',parse_dates=['Date'], dayfirst=True )
df_2 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (2).csv',parse_dates=['Date'], dayfirst=True )
df_3 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (3).csv',parse_dates=['Date'], dayfirst=True )
df_4 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (4).csv',parse_dates=['Date'], dayfirst=True )
df_5 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (5).csv',parse_dates=['Date'], dayfirst=True )
df_6 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (6).csv',parse_dates=['Date'], dayfirst=True )
df_7 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (7).csv',parse_dates=['Date'], dayfirst=True )
df_8 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (8).csv',parse_dates=['Date'], dayfirst=True )
df_9 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (9).csv',parse_dates=['Date'], dayfirst=True )
df_10 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (10).csv',parse_dates=['Date'], dayfirst=True )
df_11 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (11).csv',parse_dates=['Date'], dayfirst=True )
df_12 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (12).csv',parse_dates=['Date'], dayfirst=True )
df_13 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (13).csv',parse_dates=['Date'], dayfirst=True )
df_14 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (14).csv',parse_dates=['Date'], dayfirst=True )
df_15 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (15).csv',parse_dates=['Date'], dayfirst=True )
df_16 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (16).csv',parse_dates=['Date'], dayfirst=True )
df_17 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (17).csv',parse_dates=['Date'], dayfirst=True )
df_18 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (18).csv',parse_dates=['Date'], dayfirst=True )
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_17440\4237668305.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_5 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (5).csv',parse_dates=['Date'], dayfirst=True )
# C:\Users\Hp\AppData\Local\Temp\ipykernel_17440\4237668305.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_6 = pd.read_csv(r'C:\Users\Hp\Documents\Serie_A\csv_serie_a\I1 (6).csv',parse_dates=['Date'], dayfirst=True )
# C:\Users\Hp\AppData\Local\Temp\ipykernel_17440\4237668305.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# ...

# %%
for i in range(0, 19):
    print(f"df_{i}['Date'] = df_{i}['Date'].dt.strftime('%d/%m/%Y')")
# Out:
# df_0['Date'] = df_0['Date'].dt.strftime('%d/%m/%Y')
# df_1['Date'] = df_1['Date'].dt.strftime('%d/%m/%Y')
# df_2['Date'] = df_2['Date'].dt.strftime('%d/%m/%Y')
# df_3['Date'] = df_3['Date'].dt.strftime('%d/%m/%Y')
# df_4['Date'] = df_4['Date'].dt.strftime('%d/%m/%Y')
# df_5['Date'] = df_5['Date'].dt.strftime('%d/%m/%Y')
# df_6['Date'] = df_6['Date'].dt.strftime('%d/%m/%Y')
# df_7['Date'] = df_7['Date'].dt.strftime('%d/%m/%Y')
# df_8['Date'] = df_8['Date'].dt.strftime('%d/%m/%Y')
# df_9['Date'] = df_9['Date'].dt.strftime('%d/%m/%Y')
# df_10['Date'] = df_10['Date'].dt.strftime('%d/%m/%Y')
# df_11['Date'] = df_11['Date'].dt.strftime('%d/%m/%Y')
# df_12['Date'] = df_12['Date'].dt.strftime('%d/%m/%Y')
# df_13['Date'] = df_13['Date'].dt.strftime('%d/%m/%Y')
# df_14['Date'] = df_14['Date'].dt.strftime('%d/%m/%Y')
# df_15['Date'] = df_15['Date'].dt.strftime('%d/%m/%Y')
# df_16['Date'] = df_16['Date'].dt.strftime('%d/%m/%Y')
# df_17['Date'] = df_17['Date'].dt.strftime('%d/%m/%Y')
# ...

# %%
df_0['Date'] = df_0['Date'].dt.strftime('%d/%m/%Y')
df_1['Date'] = df_1['Date'].dt.strftime('%d/%m/%Y')
df_2['Date'] = df_2['Date'].dt.strftime('%d/%m/%Y')
df_3['Date'] = df_3['Date'].dt.strftime('%d/%m/%Y')
df_4['Date'] = df_4['Date'].dt.strftime('%d/%m/%Y')
df_5['Date'] = df_5['Date'].dt.strftime('%d/%m/%Y')
df_6['Date'] = df_6['Date'].dt.strftime('%d/%m/%Y')
df_7['Date'] = df_7['Date'].dt.strftime('%d/%m/%Y')
df_8['Date'] = df_8['Date'].dt.strftime('%d/%m/%Y')
df_9['Date'] = df_9['Date'].dt.strftime('%d/%m/%Y')
df_10['Date'] = df_10['Date'].dt.strftime('%d/%m/%Y')
df_11['Date'] = df_11['Date'].dt.strftime('%d/%m/%Y')
df_12['Date'] = df_12['Date'].dt.strftime('%d/%m/%Y')
df_13['Date'] = df_13['Date'].dt.strftime('%d/%m/%Y')
df_14['Date'] = df_14['Date'].dt.strftime('%d/%m/%Y')
df_15['Date'] = df_15['Date'].dt.strftime('%d/%m/%Y')
df_16['Date'] = df_16['Date'].dt.strftime('%d/%m/%Y')
df_17['Date'] = df_17['Date'].dt.strftime('%d/%m/%Y')
df_18['Date'] = df_18['Date'].dt.strftime('%d/%m/%Y')

# %%
# Creare una lista di DataFrame
dfs = [globals()[f"df_{i}"] for i in range(19)]

# Concatenare i DataFrame
concatenated_df = pd.concat(dfs, ignore_index=True)

# %%
concatenated_df_important = concatenated_df[['Div', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG',
                                              'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR', 'HS', 'AS', 'HST', 'AST', 'HF', 
                                              'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR','B365H','B365D','B365A']]

# %%
concatenated_df_important.isna()
# Out:
#         Div   Date   Time  HomeTeam  AwayTeam   FTHG   FTAG    FTR   HTHG  \
# 0     False  False  False     False     False  False  False  False  False
# 1     False  False  False     False     False  False  False  False  False
# 2     False  False  False     False     False  False  False  False  False
# 3     False  False  False     False     False  False  False  False  False
# 4     False  False  False     False     False  False  False  False  False
# ...     ...    ...    ...       ...       ...    ...    ...    ...    ...
# 6960  False  False  False     False     False  False  False  False  False
# 6961  False  False  False     False     False  False  False  False  False
# 6962  False  False  False     False     False  False  False  False  False
# 6963  False  False  False     False     False  False  False  False  False
# 6964  False  False  False     False     False  False  False  False  False
#
#        HTAG  ...     AF     HC     AC     HY     AY     HR     AR  B365H  \
# ...

# %%
concatenated_df_important.isna().sum().sort_values(ascending=False).head(40)
# Out:
# HST         20
# HS          20
# AST         20
# AS          20
# AC          16
# HC          16
# AF          16
# HF          16
# B365D       13
# B365H       13
# B365A       13
# HTR          7
# HTAG         7
# HTHG         7
# HY           7
# AY           6
# HR           6
# AR           6
# Date         5
# FTR          5
# FTAG         5
# FTHG         5
# AwayTeam     5
# HomeTeam     5
# Div          5
# dtype: int64

# %%
concatenated_df_important = concatenated_df_important.drop(columns=['Time'])
concatenated_df_important = concatenated_df_important.dropna(subset=['HomeTeam'])
#concatenated_df_important = concatenated_df_important.dropna(subset=['HTAG', 'AST','HY'])
concatenated_df_important['Date'] = pd.to_datetime(concatenated_df_important['Date'])
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_17440\1143043079.py:4: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   concatenated_df_important['Date'] = pd.to_datetime(concatenated_df_important['Date'])

# %%
# Selezionare solo le righe che contengono almeno un valore NaN
df_con_nan = concatenated_df_important[concatenated_df_important.isna().any(axis=1)]

# Stampare il nuovo DataFrame
df_con_nan
# Out:
#      Div       Date    HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  HTR  \
# 583   I1 2022-01-10      Torino  Fiorentina   4.0   0.0   H   3.0   0.0    H
# 795   I1 2020-10-18     Udinese       Parma   3.0   2.0   H   1.0   1.0    D
# 797   I1 2020-10-19      Verona       Genoa   0.0   0.0   D   0.0   0.0    D
# 2297  I1 2016-08-28    Sassuolo     Pescara   0.0   3.0   A   NaN   NaN  NaN
# 3288  I1 2015-03-02        Roma    Juventus   1.0   1.0   D   0.0   0.0    D
# 3836  I1 2012-09-23    Cagliari        Roma   0.0   3.0   A   NaN   NaN  NaN
# 4890  I1 2011-04-17      Chievo     Bologna   2.0   0.0   H   1.0   0.0    H
# 4892  I1 2011-04-17       Genoa     Brescia   3.0   0.0   H   0.0   0.0    D
# 5305  I1 2010-05-09     Bologna     Catania   1.0   1.0   D   1.0   0.0    H
# 6550  I1 2005-10-26       Lazio      Chievo   2.0   2.0   D   1.0   0.0    H
# 6597  I1 2005-12-04  Fiorentina    Juventus   1.0   2.0   A   1.0   1.0    D
# ...

# %%
# Ordinare il DataFrame in base alla colonna "Date" in ordine discendente
df_importanti = concatenated_df_important.sort_values(by='Date', ascending=False)
df_importanti
# Out:
#      Div       Date    HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 6964  I1 2023-11-12       Inter  Frosinone   2.0   0.0   H   1.0   0.0   H
# 6962  I1 2023-11-12     Udinese   Atalanta   1.0   1.0   D   1.0   0.0   H
# 6961  I1 2023-11-12  Fiorentina    Bologna   2.0   1.0   H   1.0   1.0   D
# 6960  I1 2023-11-12      Napoli     Empoli   0.0   1.0   A   0.0   0.0   D
# 6963  I1 2023-11-12       Lazio       Roma   0.0   0.0   D   0.0   0.0   D
# ...   ..        ...         ...        ...   ...   ...  ..   ...   ...  ..
# 6473  I1 2005-08-28       Siena   Cagliari   2.0   1.0   H   1.0   1.0   D
# 6474  I1 2005-08-28     Udinese     Empoli   1.0   0.0   H   1.0   0.0   H
# 6467  I1 2005-08-28      Ascoli      Milan   1.0   1.0   D   0.0   0.0   D
# 6465  I1 2005-08-27  Fiorentina  Sampdoria   2.0   1.0   H   2.0   0.0   H
# 6466  I1 2005-08-27     Livorno      Lecce   2.0   1.0   H   1.0   1.0   D
#
#       ...    AF   HC   AC   HY   AY   HR   AR  B365H  B365D  B365A
# ...

# %%
# Esporta il DataFrame in un file CSV
df_importanti.to_csv(r'C:\Users\Hp\Downloads\partite_serie_A.csv', index=True)
